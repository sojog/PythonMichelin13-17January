# %%
import pandas as pd

# %%
df = pd.read_csv("exemple.csv", index_col=0)
df.head()
# Out:
#     country        team  trophies
# id
# 0   England   Liverpool         6
# 1     Spain   Barcelona         5
# 2   England  Man United         3
# 3     Italy       Inter         3
# 4   England     Chelsea         2

# %%
df = pd.read_csv("exemple.csv", index_col=0)
df.head(n=2)
# Out:
#     country       team  trophies
# id
# 0   England  Liverpool         6
# 1     Spain  Barcelona         5

# %%
df = pd.read_csv("exemple.csv")
df.head(n=2)
# Out:
#    id  country       team  trophies
# 0   0  England  Liverpool         6
# 1   1    Spain  Barcelona         5

# %%
df = pd.read_csv("exemple.csv", index_col="id")
df.head(n=2)
# Out:
#     country       team  trophies
# id
# 0   England  Liverpool         6
# 1     Spain  Barcelona         5

# %%
df.dtypes
# Out:
# country     object
# team        object
# trophies     int64
# dtype: object

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.head(2)
# Out:
#     country       team  trophies
# id
# 0   England  Liverpool         6
# 1     Spain  Barcelona         5

# %%
df[['team', "country"]].head(2)
# Out:
#          team  country
# id
# 0   Liverpool  England
# 1   Barcelona    Spain

# %%
new_df = df[["trophies", "team"]].head(2)
new_df
# Out:
#     trophies       team
# id
# 0          6  Liverpool
# 1          5  Barcelona

# %%
df.head(2)
# Out:
#     country       team  trophies
# id
# 0   England  Liverpool         6
# 1     Spain  Barcelona         5

# %%
# We choose only the entries with country Spain
df[ df["country"] == "Spain" ]
# Out:
#    country       team  trophies
# id
# 1    Spain  Barcelona         5

# %%
df[ df["country"] == "Italy" ]
# Out:
#    country      team  trophies
# id
# 3    Italy     Inter         3
# 8    Italy  Juventus         2

# %%
df[ df["trophies"] == 2]
# Out:
#      country          team  trophies
# id
# 4    England       Chelsea         2
# 5    England       Chelsea         2
# 6    England  Nottm Forest         2
# 7   Portugal       Benfica         2
# 8      Italy      Juventus         2
# 9   Portugal      FC Porto         2

# %%
df[ (df["country"] == "Italy") & (df["trophies"] == 2)]
# Out:
#    country      team  trophies
# id
# 8    Italy  Juventus         2

# %%
condition1 = df["country"] == "Italy"
condition2 = df["trophies"] == 2
df[ condition1 & condition2]
# Out:
#    country      team  trophies
# id
# 8    Italy  Juventus         2

# %%
print(condition1[:4])
# Out:
# id
# 0    False
# 1    False
# 2    False
# 3     True
# Name: country, dtype: bool

# %%
condition1 = df["country"] == "Italy"
condition2 = df["country"] == "England"
condition3 = df["trophies"] == 2
df[ (condition1 | condition2) & condition3]
# Out:
#     country          team  trophies
# id
# 4   England       Chelsea         2
# 5   England       Chelsea         2
# 6   England  Nottm Forest         2
# 8     Italy      Juventus         2

# %%
condition1 = df["trophies"] == 2
condition2 = df["country"].isin(["England", "Italy"])

df[condition1 & condition2]
# Out:
#     country          team  trophies
# id
# 4   England       Chelsea         2
# 5   England       Chelsea         2
# 6   England  Nottm Forest         2
# 8     Italy      Juventus         2

# %%
df [ df[ "trophies" ] < 3    ].head(2)
# Out:
#     country     team  trophies
# id
# 4   England  Chelsea         2
# 5   England  Chelsea         2

# %%
df [ df[ "trophies" ] < 3    ].count()
# Out:
# country     16
# team        16
# trophies    16
# dtype: int64

# %%
df [ df[ "trophies" ] == 1].count()
# Out:
# country     10
# team        10
# trophies    10
# dtype: int64

# %%
england_df =  df [ df["country"] == "England" ]
england_with_2_trophies_df = england_df[england_df["trophies"] == 2]
england_with_2_trophies_df
# Out:
#     country          team  trophies
# id
# 4   England       Chelsea         2
# 5   England       Chelsea         2
# 6   England  Nottm Forest         2

# %%
england_df.sort_values("team")
# Out:
#     country          team  trophies
# id
# 14  England   Aston Villa         1
# 4   England       Chelsea         2
# 5   England       Chelsea         2
# 0   England     Liverpool         6
# 10  England      Man City         1
# 2   England    Man United         3
# 6   England  Nottm Forest         2

# %%
df.sort_values(["trophies", "team"])
# Out:
#         country           team  trophies
# id
# 14      England    Aston Villa         1
# 19     Scotland         Celtic         1
# 16       Serbia  Crvena zvezda         1
# 11      Germany       Dortmund         1
# 17      Romania           FCSB         1
# 12  Netherlands      Feyenoord         1
# 15      Germany        Hamburg         1
# 10      England       Man City         1
# 13       France      Marseille         1
# 18  Netherlands            PSV         1
# 7      Portugal        Benfica         2
# 4       England        Chelsea         2
# 5       England        Chelsea         2
# 9      Portugal       FC Porto         2
# 8         Italy       Juventus         2
# 6       England   Nottm Forest         2
# 3         Italy          Inter         3
# 2       England     Man United         3
# 1         Spain      Barcelona         5
# 0       England      Liverpool         6

# %%
df.sort_values(["trophies", "team"],ascending=False)
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool         6
# 1         Spain      Barcelona         5
# 2       England     Man United         3
# 3         Italy          Inter         3
# 6       England   Nottm Forest         2
# 8         Italy       Juventus         2
# 9      Portugal       FC Porto         2
# 4       England        Chelsea         2
# 5       England        Chelsea         2
# 7      Portugal        Benfica         2
# 18  Netherlands            PSV         1
# 13       France      Marseille         1
# 10      England       Man City         1
# 15      Germany        Hamburg         1
# 12  Netherlands      Feyenoord         1
# 17      Romania           FCSB         1
# 11      Germany       Dortmund         1
# 16       Serbia  Crvena zvezda         1
# 19     Scotland         Celtic         1
# 14      England    Aston Villa         1

# %%
df.sort_values(["trophies", "team"],ascending=(False, True))
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool         6
# 1         Spain      Barcelona         5
# 3         Italy          Inter         3
# 2       England     Man United         3
# 7      Portugal        Benfica         2
# 4       England        Chelsea         2
# 5       England        Chelsea         2
# 9      Portugal       FC Porto         2
# 8         Italy       Juventus         2
# 6       England   Nottm Forest         2
# 14      England    Aston Villa         1
# 19     Scotland         Celtic         1
# 16       Serbia  Crvena zvezda         1
# 11      Germany       Dortmund         1
# 17      Romania           FCSB         1
# 12  Netherlands      Feyenoord         1
# 15      Germany        Hamburg         1
# 10      England       Man City         1
# 13       France      Marseille         1
# 18  Netherlands            PSV         1
